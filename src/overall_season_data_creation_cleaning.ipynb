# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('../data/seasonData/overall_season_player_wise.csv')

# %%
data = data.dropna()

# %%
data = data[data.GS > 30]

# %%
data
# Out:
#     Rk              Player  Age   G  GS    MP   FG   FGA    FG%   3P  ...  \
# 0    1        Bradley Beal   29  50  50  33.5  8.9  17.6  0.506  1.6  ...
# 1    2  Kristaps Porziņģis   27  65  65  32.6  7.8  15.7  0.498  2.1  ...
# 2    3          Kyle Kuzma   27  64  64  35.0  8.0  17.8  0.448  2.5  ...
# 3    4       Rui Hachimura   24  30   0  24.3  5.3  10.8  0.488  1.0  ...
# 4    5       Corey Kispert   23  74  45  28.3  3.9   7.9  0.497  2.2  ...
# 5    6        Monte Morris   27  62  61  27.3  4.0   8.3  0.480  1.3  ...
# 6    7         Deni Avdija   22  76  40  26.6  3.3   7.6  0.437  0.9  ...
# 8    9         Will Barton   32  40   0  19.6  2.8   7.1  0.386  1.3  ...
# 9   10       Kendrick Nunn   27  31   0  14.1  2.9   6.4  0.447  1.2  ...
# 10  11        Delon Wright   30  50  14  24.4  2.8   5.8  0.474  0.8  ...
# 11  12            Jay Huff   24   7   0  13.6  2.1   3.6  0.600  0.9  ...
# 12  13      Jordan Goodwin   24  62   7  17.8  2.5   5.7  0.448  0.6  ...
# ...

# %%
data = data.sort_values(['PTS▼'], ascending=False)

# %%
data = data[data['PTS▼']>8]
data = data[data.GS>10]

# %%
data
# Out:
#    Rk              Player  Age   G  GS    MP   FG   FGA    FG%   3P  ...  \
# 0   1        Bradley Beal   29  50  50  33.5  8.9  17.6  0.506  1.6  ...
# 1   2  Kristaps Porziņģis   27  65  65  32.6  7.8  15.7  0.498  2.1  ...
# 2   3          Kyle Kuzma   27  64  64  35.0  8.0  17.8  0.448  2.5  ...
# 4   5       Corey Kispert   23  74  45  28.3  3.9   7.9  0.497  2.2  ...
# 5   6        Monte Morris   27  62  61  27.3  4.0   8.3  0.480  1.3  ...
# 6   7         Deni Avdija   22  76  40  26.6  3.3   7.6  0.437  0.9  ...
#
#      FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PTS▼
# 0  0.842  0.8  3.1  3.9  5.4  0.9  0.7  2.9  2.1  23.2
# 1  0.851  1.8  6.6  8.4  2.7  0.9  1.5  2.1  3.0  23.2
# 2  0.730  0.9  6.4  7.2  3.7  0.6  0.5  3.0  2.3  21.2
# 4  0.852  0.4  2.4  2.8  1.2  0.4  0.1  0.7  1.3  11.1
# 5  0.831  0.4  3.0  3.4  5.3  0.7  0.2  1.0  1.2  10.3
# 6  0.739  1.0  5.4  6.4  2.8  0.9  0.4  1.6  2.8   9.2
#
# [6 rows x 28 columns]

# %%
data.to_csv('../data/seasonData/season_top_player.csv')
